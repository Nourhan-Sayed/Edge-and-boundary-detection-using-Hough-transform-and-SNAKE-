# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from Utilities import *
from snakes_show import *
image2 = cv2.imread( "example.jpg", cv2.IMREAD_COLOR )
image3 = cv2.imread( "example2.jpg", cv2.IMREAD_COLOR )
image4 = cv2.imread( "example4.jpg", cv2.IMREAD_COLOR )

points =snakes(image2,15,10,7)
# print(points)
# Out:
# e:\university\3rd year 2nd term\Computer Vision\Tasks\a02-team_14\Utilities.py:192: RuntimeWarning: overflow encountered in ulong_scalars
#   sum_ = int_img[y1, x1]-int_img[y0, x1]-int_img[y1, x0]+int_img[y0, x0]
# c:\Users\HP.SXM10\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# area= 88389.0
# ............
# perimeter= 1170.7881540002618
# size 100

# %%
chain=chain_code(points)
print(chain)
# Out:
# [7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 1, 7, 7, 1, 1, 7, 1, 1, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 1, 7, 7, 1, 1, 7, 1, 1, 7]

# %%
snakes(image3,20,7,5)
# Out:
# area= 34700.0
# ............
# perimeter= 758.5859880467784

# %%
image5 = cv2.imread( "dca21be92ef10ecd0b4974fa648d6df3.jpg", cv2.IMREAD_COLOR )
snakes(image5,20,7,5)
# Out:
# c:\Users\hazem\cv-a00-starting-git-team-14\Utilities.py:192: RuntimeWarning: overflow encountered in ulong_scalars
#   sum_ = int_img[y1, x1]-int_img[y0, x1]-int_img[y1, x0]+int_img[y0, x0]
# C:\Users\hazem\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# area= 145742.0
# ............
# perimeter= 1418.4874217295906

# %%
snakes(image5,30,10,5)
# Out:
# area= 141250.0
# ............
# perimeter= 1376.8762873397338

# %%
snakes(image5,30,5,5)
# Out:
# area= 140792.0
# ............
# perimeter= 1375.858473554665
